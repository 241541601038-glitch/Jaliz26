# %%
S=input("enter a string:")
rev=S[::-1]
print("reversed string:",rev)
# Out:
# enter a string: Jaliz
# reversed string: zilaJ

# %%
n=int(input("enter a number:"))
for i in range(1,11):
   print(f"{n}*{i}={n*i}")
# Out:
# enter a number: 10
# 10*1=10
# 10*2=20
# 10*3=30
# 10*4=40
# 10*5=50
# 10*6=60
# 10*7=70
# 10*8=80
# 10*9=90
# 10*10=100
