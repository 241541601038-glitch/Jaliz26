# %%
selling_price = float(input("Enter selling price: "))
product_name=(input("enter a product name: "))
Selling_price = float(input("Enter selling price: "))
Product_name=(input("enter a product name: "))
selling_Price = float(input("Enter selling price: "))
product_Name=(input("enter a product name: "))
gst_rate = float(input("Enter GST rate (%): "))
cgst = (selling_price * gst_rate) / 200
sgst = (selling_price * gst_rate) / 200
total_tax = cgst + sgst
cgst = (Selling_price * gst_rate) / 200
sgst = (Selling_price * gst_rate) / 200
total_tax = cgst + sgst
cgst = (selling_Price * gst_rate) / 200
sgst = (selling_Price * gst_rate) / 200
total_tax = cgst + sgst
total_amount = selling_Price + total_tax + Selling_price + total_tax + selling_Price + total_tax

print("\n-------------Invoice-------------")
print(f"MALL Name:PHOENIX MALL")
print(f"Item Name1: {product_name}")
print(f"Price1: ₹{selling_price}")
print(f"Item Name2: {Product_name}")
print(f"Price2: ₹{Selling_price}")
print(f"Item Name3: {product_Name}")
print(f"Price3: ₹{selling_Price}")
print(f"GST Rate: {gst_rate}%")
print(f"CGST ({gst_rate/2}%): ₹{cgst:.2f}")
print(f"SGST ({gst_rate/2}%): ₹{sgst:.2f}")
print(f"Total Amount: ₹{total_amount:.2f}")
# Out:
# Enter selling price:  1000
# enter a product name:  3
# Enter selling price:  3698
# enter a product name:  5
# Enter selling price:  55555
# enter a product name:  5
# Enter GST rate (%):  18
# -------------Invoice-------------
# MALL Name:PHOENIX MALL
# Item Name1: 3
# Price1: ₹1000.0
# Item Name2: 5
# Price2: ₹3698.0
# Item Name3: 5
# Price3: ₹55555.0
# GST Rate: 18.0%
# CGST (9.0%): ₹4999.95
# SGST (9.0%): ₹4999.95
# Total Amount: ₹144807.70

# %%
n=int(input("enter n"))
i=1
fact=1
while(i<=n):
    fact=fact*i
    i=i+1
print(fact)
# Out:
# enter n 5
# 120

# %%
n=int(input("enter n"))
sum=0
while(n>0):
    a=n%10
    sum=sum+a
    n=n//10
print(sum)
# Out:
# enter n 123
# 6
